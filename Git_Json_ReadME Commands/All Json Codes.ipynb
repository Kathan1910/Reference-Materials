# %%
import requests

def call_api(number):
    url = f"http://192.168.20.59:8092/api/login/wappLogin"
    response = requests.get(url)

    if response.status_code == 200:
        json_data = response.json()
        return json_data
    else:
        print("Error: API request failed.")
        return None

# Example usage
number = input("Enter a number: ")
json_data = call_api(number)

if json_data is not None:
    print("JSON Data:", json_data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2616/487210327.py in <cell line: 15>()
#      13
#      14 # Example usage
# ---> 15 number = input("Enter a number: ")
#      16 json_data = call_api(number)
#      17
#
# ~/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1189             msg = "raw_input was called, but this frontend does not support input requests."
#    1190             raise StdinNotImplementedError(msg)
# -> 1191         return self._input_request(
#    1192             str(prompt),
#    1193             self._parent_ident["shell"],
#
# ~/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1232                 # re-raise KeyboardInterrupt, to truncate traceback
#    1233                 msg = "Interrupted by user"
# ...

# %%
import requests

def get_json_data(number):
    url = "http://192.168.20.59:8092/api/login/wappLogin"
    data = {
        "mobileNo": number
    }

    response = requests.post(url, json=data)

    if response.status_code == 200:
        json_data = response.json()
        return json_data
    else:
        print("Error: API request failed.")
        return None

# Example usage
number = input("Enter a mobile number: ")
json_data = get_json_data(number)

if json_data is not None:
    print("JSON Data:", json_data)
# Out:
# Enter a mobile number: 8764273679
# ...

# %%
import requests

def get_json_data(number):
    url = "http://192.168.20.59:8092/api/login/wappLogin"
    data = {
        "mobileNo": number
    }

    response = requests.post(url, json=data)

    if response.status_code == 200:
        json_data = response.json()
        token = json_data.get("token")
        return token
    else:
        print("Error: API request failed.")
        return None

# Example usage
number = input("Enter a mobile number: ")
token = get_json_data(number)

if token is not None:
    print("Token:", token)
# Out:
# Enter a mobile number: 8764273679

# %%
import requests

def get_token(number):
    url = "http://192.168.20.59:8092/api/login/wappLogin"
    data = {
        "mobileNo": number
    }

    response = requests.post(url, json=data)

    if response.status_code == 200:
        json_data = response.json()

        # Traverse through the nested structure to find the "token" key
        for item in json_data:
            if isinstance(item, dict) and "token" in item:
                token = item["token"]
                return token

        # If "token" key is not found
        print("Error: 'token' key not found in the JSON response.")
        return None
    else:
        print("Error: API request failed.")
        return None

# Example usage
number = input("Enter a mobile number: ")
token = get_token(number)

if token is not None:
    print("Token:", token)
# Out:
# Enter a mobile number: 8764273679
# Error: 'token' key not found in the JSON response.

# %%
def fetch_token(json_data):
    # Traverse through the nested structure to find the "token" key
    for item in json_data:
        if isinstance(item, dict) and "token" in item:
            token = item["token"]
            return token

    # If "token" key is not found
    print("Error: 'token' key not found in the JSON data.")
    return None

# %%
import requests

def get_token(number):
    url = "http://192.168.20.59:8092/api/login/wappLogin"
    data = {
        "mobileNo": number
    }

    response = requests.post(url, json=data)

    if response.status_code == 200:
        json_data = response.json()
        token = fetch_token(json_data)
        if token is not None:
            return token
        else:
            return None
    else:
        print("Error: API request failed.")
        return None

# Example usage
number = input("Enter a mobile number: ")
token = get_token(number)

if token is not None:
    print("Token:", token)
# Out:
# Enter a mobile number: 8764273679
# Error: 'token' key not found in the JSON data.

# %%
import requests

def get_token(number):
    url = "http://192.168.20.59:8092/api/login/wappLogin"
    data = {
        "mobileNo": number
    }

    response = requests.post(url, json=data)

    if response.status_code == 200:
        json_data = response.json()

        # Fetch the value of 'token' from JSON data
        token = json_data['data']['token']
        return token
    else:
        print("Error: API request failed.")
        return None

# Example usage
number = input("Enter a mobile number: ")
token = get_token(number)

if token is not None:
    print("Token:", token)
# Out:
# Enter a mobile number: 8764273679
# Token: MJxlyVGemJUfowNJ0l0JDckApJFH8cR7

# %%
import requests

def get_project_info():
    url = "http://192.168.20.59:8092/api/login/wappLogin"  # Replace with your API endpoint
    data = {
        "mobileNo": "8764273679"
    }
    response = requests.get(url)

    if response.status_code == 200:
        json_data = response.json()

        # Fetch the value of 'prj_config' from JSON data
        prj_config = json_data['data']['user_config']['prj_config']

        project_info = []
        for item in prj_config:
            project_name = item['project_name']
            project_desc = item['project_desc']
            project_info.append({"name": project_name, "description": project_desc})

        return prj_config
    else:
        print("Error: API request failed.")
        return []

# Example usage
projects = get_project_info()

if projects:
    print("Project Information:")
    for project in projects:
        print("Name:", project["name"])
        print("Description:", project["description"])
        print()
# Out:
# Error: API request failed.

# %%
prj_config = json_data['data']['user_config']['prj_config']

for key, value in prj_config.items():
    project_name = value['project_name']
    print(project_name)
    # or use dispatcher.utter_message(text=project_name) for your specific use case
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2616/3945223277.py in <cell line: 1>()
# ----> 1 prj_config = json_data['data']['user_config']['prj_config']
#       2
#       3 for key, value in prj_config.items():
#       4     project_name = value['project_name']
#       5     print(project_name)
#
# NameError: name 'json_data' is not defined

# %%
import requests

def fetch_project_names(json_data):
    project_names = []
    
    if 'data' in json_data and 'user_config' in json_data['data'] and 'prj_config' in json_data['data']['user_config']:
        prj_config = json_data['data']['user_config']['prj_config']
        
        for item in prj_config:
            project_name = item.get('project_name')
            if project_name:
                project_names.append(project_name)
    
    return project_names

def get_json_data(number):
    url = "http://192.168.20.59:8092/api/login/wappLogin"
    data = {
        "mobileNo": number
    }

    response = requests.post(url, json=data)

    if response.status_code == 200:
        json_data = response.json()
        return json_data
    else:
        print("Error: API request failed.")
        return None

# Example usage
number = input("Enter a mobile number: ")
json_data = get_json_data(number)

if json_data is not None:
    names = fetch_project_names(json_data)
    print(names)  # Output: ['Project 1', 'Project 2']
# Out:
# Enter a mobile number: 8764273679
# ['p1', 'vmc project']

# %%
import requests

def fetch_project_names(json_data):
    project_names = []
    
    if 'data' in json_data and 'user_config' in json_data['data'] and 'prj_config' in json_data['data']['user_config']:
        prj_config = json_data['data']['user_config']['prj_config']
        
        for item in prj_config:
            project_name = item.get('project_name')
            if project_name:
                project_names.append(project_name)
    
    return project_names

def fetch_access_levels(json_data):
    access_levels = []
    
    if 'data' in json_data and 'user_config' in json_data['data'] and 'access_config' in json_data['data']['user_config']:
        access_config = json_data['data']['user_config']['access_config']
        access_levels = access_config.get('access_levels', [])
    
    return access_levels

def get_json_data(number):
    url = "http://192.168.20.59:8092/api/login/wappLogin"
    data = {
        "mobileNo": number
    }

    response = requests.post(url, json=data)

    if response.status_code == 200:
        json_data = response.json()
        return json_data
    else:
        print("Error: API request failed.")
        return None

def fetch_project_details(project):
    url = "http://your-api-url"
    data = {
        "project": project
    }

    response = requests.post(url, json=data)

    if response.status_code == 200:
        json_data = response.json()
        return json_data
    else:
        print("Error: API request failed.")
        return None

def select_project(names):
    print("Select a project:")
    for i, name in enumerate(names, 1):
        print(f"{i}. {name}")
    
    choice = input("Enter the project number: ")
    choice_index = int(choice) - 1
    
    if choice_index >= 0 and choice_index < len(names):
        return names[choice_index]
    else:
        print("Invalid choice. Please try again.")
        return None

# Example usage
number = input("Enter a mobile number: ")
json_data = get_json_data(number)

if json_data is not None:
    names = fetch_project_names(json_data)
    selected_project = select_project(names)
    
    if selected_project is not None:
        print("Selected project:", selected_project)
        project_details = fetch_project_details(selected_project)
        
        if project_details is not None:
            print("Project details:", project_details)
            
            access_levels = fetch_access_levels(json_data)
            print("Access Levels:")
            for level in access_levels:
                print(level)
# Out:
# Enter a mobile number: 8764273679
# Select a project:
# 1. p1
# 2. vmc project
# Enter the project number: 1
# Selected project: p1
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/urllib3/connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/anaconda3/lib/python3.9/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      71
# ---> 72     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73         af, socktype, proto, canonname, sa = res
#
# ~/anaconda3/lib/python3.9/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     953     addrlist = []
# ...

# %%
def fetch_access_levels(json_data):
    access_levels = []

    if 'access_config' in json_data:
        access_config = json_data['access_config']
        if 'access_levels' in access_config:
            access_levels = access_config['access_levels']

    return access_levels



access_levels = fetch_access_levels(json_data)

for index, level in enumerate(access_levels):
    print(f"{index} : {level}")
# Out:
# 0 : vmc_zone
# 1 : vmc_ward

# %%
import requests

def get_json_data(number):
    url = "http://192.168.20.59:8092/api/login/wappLogin"
    data = {
        "mobileNo": number
    }

    response = requests.post(url, json=data)

    if response.status_code == 200:
        json_data = response.json()
        return json_data
    else:
        print("Error: API request failed.")
        return None


def fetch_access_levels(number):
    json_data = get_json_data(number)

    if json_data is not None and 'data' in json_data and 'user_config' in json_data['data'] and 'access_config' in json_data['data']['user_config']:
        access_config = json_data['data']['user_config']['access_config']
        
        access_levels = []
        for module_key, module_value in access_config.items():
            print(f"Module Key: {module_key}")
            print(f"Module Value: {module_value}")
            if isinstance(module_value, dict) and 'access_levels' in module_value:
                print("Access Levels Found")
                access_levels.extend(module_value['access_levels'])

        return access_levels

    print("Error: Failed to fetch access levels.")
    return None


# Example usage
number = input("Enter a mobile number: ")
access_levels = fetch_access_levels(number)

if access_levels is not None:
    for index, level in enumerate(access_levels):
        print(f"{index + 1}. {level}")
# Out:
# Enter a mobile number: 8764273679
# Module Key: 81
# Module Value: [{'access_levels': ['vmc_zone', 'vmc_ward'], 'access_category_id': [788, 789], 'access_id': 81, 'access_theme_name': 'vmc_access'}]

# %%
import requests

def get_json_data(number):
    url = "http://192.168.20.59:8092/api/login/wappLogin"
    data = {
        "mobileNo": number
    }

    response = requests.post(url, json=data)

    if response.status_code == 200:
        json_data = response.json()
        return json_data
    else:
        print("Error: API request failed.")
        return None


def fetch_access_levels(number):
    json_data = get_json_data(number)

    if json_data is not None and 'data' in json_data and 'user_config' in json_data['data'] and 'access_config' in json_data['data']['user_config']:
        access_config = json_data['data']['user_config']['access_config']
        
        access_levels = []
        for module_value in access_config.values():
            if isinstance(module_value, list):
                for module in module_value:
                    if 'access_levels' in module:
                        access_levels.extend(module['access_levels'])

        return access_levels

    print("Error: Failed to fetch access levels.")
    return None


# Example usage
number = input("Enter a mobile number: ")
access_levels = fetch_access_levels(number)

if access_levels is not None:
    for index, level in enumerate(access_levels):
        print(f"{index + 1}. {level}")
# Out:
# Enter a mobile number: 8764273679
# 1. vmc_zone
# 2. vmc_ward

# %%
import requests

def get_json_data(number):
    url = "http://192.168.20.59:8092/api/login/wappLogin"
    data = {
        "mobileNo": number
    }

    response = requests.post(url, json=data)

    if response.status_code == 200:
        json_data = response.json()
        return json_data
    else:
        print("Error: API request failed.")
        return None

    
def fetch_project_names(json_data):
    project_names = []
    
    if 'data' in json_data and 'user_config' in json_data['data'] and 'prj_config' in json_data['data']['user_config']:
        prj_config = json_data['data']['user_config']['prj_config']
        
        for item in prj_config:
            project_name = item.get('project_name')
            if project_name:
                project_names.append(project_name)
    
    return project_names
   
    
def select_project(names):
    print("Select a project:")
    for i, name in enumerate(names, 1):
        print(f"{i}. {name}")
    
    choice = input("Enter the project number: ")
    choice_index = int(choice) - 1
    
    if choice_index >= 0 and choice_index < len(names):
        return names[choice_index]
    else:
        print("Invalid choice. Please try again.")
        return None

    
def fetch_access_levels(json_data, selected_project):
    access_levels = []
    
    if 'data' in json_data and 'user_config' in json_data['data'] and 'access_config' in json_data['data']['user_config']:
        access_config = json_data['data']['user_config']['access_config']
        
        for module in access_config.values():
            if isinstance(module, dict) and module.get('access_theme_name') == selected_project:
                access_levels = module.get('access_levels', [])
                break
    
    return access_levels


number = input("Enter a mobile number: ")
json_data = get_json_data(number)

if json_data is not None:
    names = fetch_project_names(json_data)
    selected_project = select_project(names)
    
    if selected_project is not None:
        print("Selected project:", selected_project)
        
        access_levels = fetch_access_levels(json_data, selected_project)
        print("Access Levels:")
        for level in access_levels:
            print(level)
            
        # Further processing based on access levels
        # Your code here
# Out:
# Enter a mobile number: 8764273679
# Select a project:
# 1. p1
# 2. vmc project
# Enter the project number: 1
# Selected project: p1
# Access Levels:

# %%
import requests

def get_json_data(number):
    url = "http://192.168.20.59:8092/api/login/wappLogin"
    data = {
        "mobileNo": number
    }

    response = requests.post(url, json=data)

    if response.status_code == 200:
        json_data = response.json()
        return json_data
    else:
        print("Error: API request failed.")
        return None

def fetch_project_names(json_data):
    project_names = []
    
    if 'data' in json_data and 'user_config' in json_data['data'] and 'prj_config' in json_data['data']['user_config']:
        prj_config = json_data['data']['user_config']['prj_config']
        
        for item in prj_config:
            project_name = item.get('project_name')
            if project_name:
                project_names.append(project_name)
    
    return project_names

def select_project(names):
    print("Select a project:")
    for i, name in enumerate(names, 1):
        print(f"{i}. {name}")
    
    choice = input("Enter the project number: ")
    choice_index = int(choice) - 1
    
    if choice_index >= 0 and choice_index < len(names):
        return names[choice_index]
    else:
        print("Invalid choice. Please try again.")
        return None

def fetch_access_levels(json_data, selected_project):
    access_levels = []
    
    if 'data' in json_data and 'user_config' in json_data['data'] and 'access_config' in json_data['data']['user_config']:
        access_config = json_data['data']['user_config']['access_config']
        
        for module_value in access_config.values():
            if isinstance(module_value, list):
                for module in module_value:
                    if 'access_theme_name' in module and module['access_theme_name'] == selected_project and 'access_levels' in module:
                        access_levels.extend(module['access_levels'])
    
    return access_levels

# Example usage
number = input("Enter a mobile number: ")
json_data = get_json_data(number)

if json_data is not None:
    names = fetch_project_names(json_data)
    selected_project = select_project(names)
    
    if selected_project is not None:
        print("Selected project:", selected_project)
        
        access_levels = fetch_access_levels(json_data, selected_project)
        print("Access Levels:")
        for index, level in enumerate(access_levels, 1):
            print(f"{index}. {level}")
# Out:
# Enter a mobile number: 8764273679
# Select a project:
# 1. p1
# 2. vmc project
# Enter the project number: 1
# Selected project: p1
# Access Levels:

# %% [markdown]
# # Sample

# %%
import requests
import json

# API endpoint URL
url = "http://192.168.20.61:8080/geoportal/api/dashboard/getDashboardLayers"

# Make a GET request to the API
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the JSON response
    json_data = response.json()

    # Print the JSON data
    print(json_data)
else:
    # Print an error message if the request failed
    print("API request failed:", response.status_code)
# Out:
# API request failed: 405

# %%
import requests

url = "http://192.168.20.61:8080/geoportal/api/dashboard/getDashboardLayers"
data = {"orgId": 234, "usertype": 3, "page": 1, "start": 0, "limit": 25}
headers = {
    "X-Auth-Token": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW"
}

response = requests.post(url, json=data, headers=headers)

if response.status_code == 200:
    json_data = response.json()
    print("JSON response:")
    print(json_data)
else:
    print(f"API request failed with status code {response.status_code}")
# Out:
# JSON response:
# ...

# %%
import requests

def fetch_json_data(url, data, headers):
    response = requests.post(url, json=data, headers=headers)
    
    if response.status_code == 200:
        json_data = response.json()
        return json_data
    else:
        print("Error: API request failed.")
        return None

def print_col_aliases(json_data):
    if 'data' in json_data and 'layers' in json_data['data']:
        layers = json_data['data']['layers']
        
        for layer in layers:
            if 'attributes' in layer:
                attributes = layer['attributes']
                
                for attribute in attributes:
                    col_alias = attribute.get('col_alias')
                    
                    if col_alias:
                        print(col_alias)

# Define the URL, data, and headers for the API call
url = "http://192.168.20.61:8080/geoportal/api/dashboard/getDashboardLayers"
data = {"orgId": 234, "usertype": 3, "page": 1, "start": 0, "limit": 25}
headers = {
    "X-Auth-Token": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW"
}

# Fetch JSON data from the API
json_data = fetch_json_data(url, data, headers)

if json_data:
    # Print the col_alias values from the JSON data
    print_col_aliases(json_data)
# Out:
# fire_stati
# fire_station_name
# no_of_ambu
# no_of_fire
# vehcl_id
# road_name
# road_type
# road_width
# slum_name

# %%
from rasa_sdk import Tracker
from rasa_sdk.executor import CollectingDispatcher
from typing import Any, Dict, List, Text
from requests.models import Response
import requests


def test_fetch_and_print_col_aliases(selected_category: str) -> None:
    url = "http://192.168.20.61:8080/geoportal/api/dashboard/getDashboardLayers"
    data = {"orgId": 234, "usertype": 3, "page": 1, "start": 0, "limit": 25}
    headers = {"X-Auth-Token": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW"}

    response = requests.post(url, json=data, headers=headers)

    if response.status_code == 200:
        json_data = response.json()

        if 'data' in json_data and 'layers' in json_data['data']:
            layers = json_data['data']['layers']

            for layer in layers:
                if layer['cat_name'] == selected_category:
                    attributes = layer.get('attributes', [])

                    if attributes:
                        col_aliases = [attr['col_alias'] for attr in attributes]
                        print("Attributes:")
                        print('\n'.join(col_aliases))
                    else:
                        print(f"No attributes found for the category {selected_category}.")
                    break
            else:
                print(f"No layer found for the category {selected_category}.")

    else:
        print("Error: API request failed.")


# Test the action with a selected category
test_fetch_and_print_col_aliases("Road_centerline")
# Out:
# Attributes:
# road_name
# road_type
# road_width

# %%
def get_json_data():
    url = "http://192.168.20.59:8092/api/report/getDashBoardReport"
    data = {
        "categoryId": 791,
        "layername": "tbl_road_centerline",
        "attribute": "road_type",
        "extent": "298542D4353500004C2455193D2797C328187D4353500004C2477208D2797",
        "no_class": 3,
        "orgId": 234,
        "type": "distinct",
        "user_access": {
            "theme": 81,
            "vmc_zone": "",
            "vmc_ward": ""
        },
        "epsg": 32643,
        "userType": 3,
        "prjid": 74,
        "pageLayout": "A4_portrait",
        "data": {
            "layout": "A4 Portrait",
            "srs": "EPSG:32643",
            "units": "m",
            "dpi": "56",
            "outputFilename": "mapprint",
            "outputFormat": "pdf",
            "orgImage": "234.png",
            "layers": [
                {
                    "type": "OSM",
                    "baseURL": "https:\/\/b.tile.openstreetmap.org",
                    "singleTile": False,
                    "tileSize": [
                        256,
                        256
                    ],
                    "maxExtent": [
                        -2.00375083392E7,
                        -2.00375083392E7,
                        2.00375083392E7,
                        2.00375083392E7
                    ],
                    "resolutions": [
                        156543.03390625,
                        78271.516953125,
                        39135.758475,
                        19567.8792375,
                        9783.93961875,
                        4891.969809375,
                        2445.9849046875,
                        1222.99245256282,
                        611.496226171875,
                        305.7481130859375,
                        152.87405654296876,
                        76.43702827148438,
                        38.21851413574219,
                        19.109257067871095,
                        9.554628533935547,
                        4.777314266967774,
                        2.388657133483887,
                        1.1943285667419434,
                        0.5971642833709717,
                        0.41999977320012255,
                        0.2799998488000817,
                        0.13999992440004086,
                        0.08399995464002451,
                        0.05599996976001634,
                        0.02799998488000817
                    ],
                    "extension": "png"
                },
                {
                    "authkey": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW",
                    "customParams": {
                        "env": "map_type:map",
                        "viewparams": "category_id:788;style_col_name:0;usertype:3;username:kushal88;cond:;gridparam:;order_col:;qrytype:0;dist:0;reverse_q:0;splfltrtype:st_intersects;refecatid:0;wkt:'';prjid:74;"
                    },
                    "styles": [
                        "234_132_307_ts"
                    ],
                    "tiled": True,
                    "format": "image/png",
                    "srs": "EPSG:32643",
                    "layers": [
                        "citylayers4:overlay_ts_bbox_32643"
                    ],
                    "type": "wms",
                    "name": "Vmc_zone",
                    "baseURL": "http://192.168.20.59:8087/geoserver/"
                },
                {
                    "authkey": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW",
                    "customParams": {
                        "env": "map_type:map",
                        "viewparams": "category_id:789;style_col_name:0;usertype:3;username:kushal88;cond:;gridparam:;order_col:;qrytype:0;dist:0;reverse_q:0;splfltrtype:st_intersects;refecatid:0;wkt:'';prjid:74;"
                    },
                    "styles": [
                        "234_132_306_ts"
                    ],
                    "tiled": True,
                    "format": "image/png",
                    "srs": "EPSG:32643",
                    "layers": [
                        "citylayers4:overlay_ts_bbox_32643"
                    ],
                    "type": "wms",
                    "name": "Vmc_ward",
                    "baseURL": "http://192.168.20.59:8087/geoserver/"
                },
                {
                    "authkey": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW",
                    "customParams": {
                        "time": 1684911532619,
                        "env": "map_type:map",
                        "viewparams": "category_id:790;usertype:3;username:kushal88;qrytype:0;dist:0;splfltrtype:st;wkt:'';prjid:74;user_access:{\"theme\":81\\,\"vmc_zone\":\"\"\\,\"vmc_ward\":\"\"};match:AND;gridparam: "
                    },
                    "styles": [
                        "234_133_390_ts"
                    ],
                    "tiled": True,
                    "format": "image/png",
                    "srs": "EPSG:32643",
                    "layers": [
                        "citylayers4:overlay_ts_bbox_32643"
                    ],
                    "type": "wms",
                    "name": "Fire_station",
                    "baseURL": "http://192.168.20.59:8087/geoserver/"
                },
                {
                    "type": "Vector",
                    "styles": {
                        "1": {
                            "strokeColor": "#ffe085",
                            "strokeWidth": 5,
                            "fillOpacity": 0.2,
                            "fillColor": "#FFFFFF"
                        }
                    },
                    "name": "Measure",
                    "geoJson": {
                        "type": "FeatureCollection",
                        "features": []
                    },
                    "styleProperty": "layer_type"
                }
            ],
            "pages": [
                {
                    "mapTitle": "sf fsf fs sf scheduled",
                    "comment": "sf fsf fs sf scheduled",
                    "bbox": [
                        298542.4353500004,
                        2455193.2797,
                        328187.4353500004,
                        2477208.2797
                    ],
                    "rotation": 0
                }
            ],
            "legends": []
        },
        "url": "http://192.168.20.59:8087/geoserver/pdf/create.json?authkey=8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW"
    }
    headers = {"X-Auth-Token": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW"}

    response = requests.post(url, json=data,headers=headers)

    if response.status_code == 200:
        json_data = response.json()
        return json_data
    else:
        print("Error: API request failed.")
        return None

# %%
json_data = get_json_data()
if json_data is not None:
    print("JSON Data:", json_data)
# Out:
# JSON Data: {'success': True, 'message': 'Successful', 'data': {'file': '...', 'prj_id': 74, 'user_id': 133, 'org_id': 234, 'report_json': {'extent': '298542D4353500004C2455193D2797C328187D4353500004C2477208D2797', 'pageLayout': 'A4_portrait', 'data': {'layout': 'A4 Portrait Report', 'srs': 'EPSG:32643', 'units': 'm', 'dpi': '56', 'outputFilename': 'mapprint', 'outputFormat': 'pdf', 'orgImage': '234.png', 'layers': [{'type': 'OSM', 'baseURL': 'https:\\/\\/b.tile.openstreetmap.org', 'singleTile': False, 'tileSize': [256, 256], 'maxExtent': [-20037508.3392, -20037508.3392, 20037508.3392, 20037508.3392], 'resolutions': [156543.03390625, 78271.516953125, 39135.758475, 19567.8792375, 9783.93961875, 4891.969809375, 2445.9849046875, 1222.99245256282, 611.496226171875, 305.7481130859375, 152.87405654296876, 76.43702827148438, 38.21851413574219, 19.109257067871095, 9.554628533935547, 4.777314266967774, 2.388657133483887, 1.1943285667419434, 0.5971642833709717, 0.41999977320012255, 0.2799998488
# ...

# %%
import requests
import shutil

def get_json_data():
    url = "http://192.168.20.59:8092/api/report/getDashBoardReport"
    data = {
        "categoryId": 791,
        "layername": "tbl_road_centerline",
        "attribute": "road_type",
        "extent": "298542D4353500004C2455193D2797C328187D4353500004C2477208D2797",
        "no_class": 3,
        "orgId": 234,
        "type": "distinct",
        "user_access": {
            "theme": 81,
            "vmc_zone": "",
            "vmc_ward": ""
        },
        "epsg": 32643,
        "userType": 3,
        "prjid": 74,
        "pageLayout": "A4_portrait",
        "data": {
            "layout": "A4 Portrait",
            "srs": "EPSG:32643",
            "units": "m",
            "dpi": "56",
            "outputFilename": "mapprint",
            "outputFormat": "pdf",
            "orgImage": "234.png",
            "layers": [
                {
                    "type": "OSM",
                    "baseURL": "https:\/\/b.tile.openstreetmap.org",
                    "singleTile": False,
                    "tileSize": [
                        256,
                        256
                    ],
                    "maxExtent": [
                        -2.00375083392E7,
                        -2.00375083392E7,
                        2.00375083392E7,
                        2.00375083392E7
                    ],
                    "resolutions": [
                        156543.03390625,
                        78271.516953125,
                        39135.758475,
                        19567.8792375,
                        9783.93961875,
                        4891.969809375,
                        2445.9849046875,
                        1222.99245256282,
                        611.496226171875,
                        305.7481130859375,
                        152.87405654296876,
                        76.43702827148438,
                        38.21851413574219,
                        19.109257067871095,
                        9.554628533935547,
                        4.777314266967774,
                        2.388657133483887,
                        1.1943285667419434,
                        0.5971642833709717,
                        0.41999977320012255,
                        0.2799998488000817,
                        0.13999992440004086,
                        0.08399995464002451,
                        0.05599996976001634,
                        0.02799998488000817
                    ],
                    "extension": "png"
                },
                {
                    "authkey": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW",
                    "customParams": {
                        "env": "map_type:map",
                        "viewparams": "category_id:788;style_col_name:0;usertype:3;username:kushal88;cond:;gridparam:;order_col:;qrytype:0;dist:0;reverse_q:0;splfltrtype:st_intersects;refecatid:0;wkt:'';prjid:74;"
                    },
                    "styles": [
                        "234_132_307_ts"
                    ],
                    "tiled": True,
                    "format": "image/png",
                    "srs": "EPSG:32643",
                    "layers": [
                        "citylayers4:overlay_ts_bbox_32643"
                    ],
                    "type": "wms",
                    "name": "Vmc_zone",
                    "baseURL": "http://192.168.20.59:8087/geoserver/"
                },
                {
                    "authkey": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW",
                    "customParams": {
                        "env": "map_type:map",
                        "viewparams": "category_id:789;style_col_name:0;usertype:3;username:kushal88;cond:;gridparam:;order_col:;qrytype:0;dist:0;reverse_q:0;splfltrtype:st_intersects;refecatid:0;wkt:'';prjid:74;"
                    },
                    "styles": [
                        "234_132_306_ts"
                    ],
                    "tiled": True,
                    "format": "image/png",
                    "srs": "EPSG:32643",
                    "layers": [
                        "citylayers4:overlay_ts_bbox_32643"
                    ],
                    "type": "wms",
                    "name": "Vmc_ward",
                    "baseURL": "http://192.168.20.59:8087/geoserver/"
                },
                {
                    "authkey": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW",
                    "customParams": {
                        "time": 1684911532619,
                        "env": "map_type:map",
                        "viewparams": "category_id:790;usertype:3;username:kushal88;qrytype:0;dist:0;splfltrtype:st;wkt:'';prjid:74;user_access:{\"theme\":81\\,\"vmc_zone\":\"\"\\,\"vmc_ward\":\"\"};match:AND;gridparam: "
                    },
                    "styles": [
                        "234_133_390_ts"
                    ],
                    "tiled": True,
                    "format": "image/png",
                    "srs": "EPSG:32643",
                    "layers": [
                        "citylayers4:overlay_ts_bbox_32643"
                    ],
                    "type": "wms",
                    "name": "Fire_station",
                    "baseURL": "http://192.168.20.59:8087/geoserver/"
                },
                {
                    "type": "Vector",
                    "styles": {
                        "1": {
                            "strokeColor": "#ffe085",
                            "strokeWidth": 5,
                            "fillOpacity": 0.2,
                            "fillColor": "#FFFFFF"
                        }
                    },
                    "name": "Measure",
                    "geoJson": {
                        "type": "FeatureCollection",
                        "features": []
                    },
                    "styleProperty": "layer_type"
                }
            ],
            "pages": [
                {
                    "mapTitle": "sf fsf fs sf scheduled",
                    "comment": "sf fsf fs sf scheduled",
                    "bbox": [
                        298542.4353500004,
                        2455193.2797,
                        328187.4353500004,
                        2477208.2797
                    ],
                    "rotation": 0
                }
            ],
            "legends": []
        },
        "url": "http://192.168.20.59:8087/geoserver/pdf/create.json?authkey=8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW"
        }
    headers = {"X-Auth-Token": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW"}

    response = requests.post(url, json=data, headers=headers)

    if response.status_code == 200:
        json_data = response.json()
        binary_data = json_data.get('data')
        if binary_data:
            pdf_binary = binary_data.get('pdf')
            if pdf_binary:
                with open('output.pdf', 'wb') as file:
                    file.write(pdf_binary)
                print("PDF file downloaded.")
            else:
                print("Error: PDF binary data not found in the response.")
        else:
            print("Error: Binary data not found in the response.")
    else:
        print("Error: API request failed.")

get_json_data()
# Out:
# Error: PDF binary data not found in the response.

# %%
import requests
import json
import base64

def get_json_data():
    url = "http://192.168.20.59:8092/api/report/getDashBoardReport"
    data = {
        "categoryId": 791,
        "layername": "tbl_road_centerline",
        "attribute": "road_type",
        "extent": "298542D4353500004C2455193D2797C328187D4353500004C2477208D2797",
        "no_class": 3,
        "orgId": 234,
        "type": "distinct",
        "user_access": {
            "theme": 81,
            "vmc_zone": "",
            "vmc_ward": ""
        },
        "epsg": 32643,
        "userType": 3,
        "prjid": 74,
        "pageLayout": "A4_portrait",
        "data": {
            "layout": "A4 Portrait",
            "srs": "EPSG:32643",
            "units": "m",
            "dpi": "56",
            "outputFilename": "mapprint",
            "outputFormat": "pdf",
            "orgImage": "234.png",
            "layers": [
                {
                    "type": "OSM",
                    "baseURL": "https:\/\/b.tile.openstreetmap.org",
                    "singleTile": False,
                    "tileSize": [
                        256,
                        256
                    ],
                    "maxExtent": [
                        -2.00375083392E7,
                        -2.00375083392E7,
                        2.00375083392E7,
                        2.00375083392E7
                    ],
                    "resolutions": [
                        156543.03390625,
                        78271.516953125,
                        39135.758475,
                        19567.8792375,
                        9783.93961875,
                        4891.969809375,
                        2445.9849046875,
                        1222.99245256282,
                        611.496226171875,
                        305.7481130859375,
                        152.87405654296876,
                        76.43702827148438,
                        38.21851413574219,
                        19.109257067871095,
                        9.554628533935547,
                        4.777314266967774,
                        2.388657133483887,
                        1.1943285667419434,
                        0.5971642833709717,
                        0.41999977320012255,
                        0.2799998488000817,
                        0.13999992440004086,
                        0.08399995464002451,
                        0.05599996976001634,
                        0.02799998488000817
                    ],
                    "extension": "png"
                },
                {
                    "authkey": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW",
                    "customParams": {
                        "env": "map_type:map",
                        "viewparams": "category_id:788;style_col_name:0;usertype:3;username:kushal88;cond:;gridparam:;order_col:;qrytype:0;dist:0;reverse_q:0;splfltrtype:st_intersects;refecatid:0;wkt:'';prjid:74;"
                    },
                    "styles": [
                        "234_132_307_ts"
                    ],
                    "tiled": True,
                    "format": "image/png",
                    "srs": "EPSG:32643",
                    "layers": [
                        "citylayers4:overlay_ts_bbox_32643"
                    ],
                    "type": "wms",
                    "name": "Vmc_zone",
                    "baseURL": "http://192.168.20.59:8087/geoserver/"
                },
                {
                    "authkey": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW",
                    "customParams": {
                        "env": "map_type:map",
                        "viewparams": "category_id:789;style_col_name:0;usertype:3;username:kushal88;cond:;gridparam:;order_col:;qrytype:0;dist:0;reverse_q:0;splfltrtype:st_intersects;refecatid:0;wkt:'';prjid:74;"
                    },
                    "styles": [
                        "234_132_306_ts"
                    ],
                    "tiled": True,
                    "format": "image/png",
                    "srs": "EPSG:32643",
                    "layers": [
                        "citylayers4:overlay_ts_bbox_32643"
                    ],
                    "type": "wms",
                    "name": "Vmc_ward",
                    "baseURL": "http://192.168.20.59:8087/geoserver/"
                },
                {
                    "authkey": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW",
                    "customParams": {
                        "time": 1684911532619,
                        "env": "map_type:map",
                        "viewparams": "category_id:790;usertype:3;username:kushal88;qrytype:0;dist:0;splfltrtype:st;wkt:'';prjid:74;user_access:{\"theme\":81\\,\"vmc_zone\":\"\"\\,\"vmc_ward\":\"\"};match:AND;gridparam: "
                    },
                    "styles": [
                        "234_133_390_ts"
                    ],
                    "tiled": True,
                    "format": "image/png",
                    "srs": "EPSG:32643",
                    "layers": [
                        "citylayers4:overlay_ts_bbox_32643"
                    ],
                    "type": "wms",
                    "name": "Fire_station",
                    "baseURL": "http://192.168.20.59:8087/geoserver/"
                },
                {
                    "type": "Vector",
                    "styles": {
                        "1": {
                            "strokeColor": "#ffe085",
                            "strokeWidth": 5,
                            "fillOpacity": 0.2,
                            "fillColor": "#FFFFFF"
                        }
                    },
                    "name": "Measure",
                    "geoJson": {
                        "type": "FeatureCollection",
                        "features": []
                    },
                    "styleProperty": "layer_type"
                }
            ],
            "pages": [
                {
                    "mapTitle": "sf fsf fs sf scheduled",
                    "comment": "sf fsf fs sf scheduled",
                    "bbox": [
                        298542.4353500004,
                        2455193.2797,
                        328187.4353500004,
                        2477208.2797
                    ],
                    "rotation": 0
                }
            ],
            "legends": []
        },
        "url": "http://192.168.20.59:8087/geoserver/pdf/create.json?authkey=8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW"
    }
    headers = {"X-Auth-Token": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW"}

    response = requests.post(url, json=data, headers=headers)

    if response.status_code == 200:
        json_data = response.json()
        print(json.dumps(json_data, indent=4))  # Print the JSON response for inspection
        
        file_value = json_data.get('data', {}).get('file')
        if file_value:
            pdf_data = base64.b64decode(file_value)
            with open('output.pdf', 'wb') as file:
                file.write(pdf_data)
            print("PDF file downloaded.")
        else:
            print("Error: File value not found in the response.")
    else:
        print("Error: API request failed.")

get_json_data()
# Out:
# {
#     "success": true,
#     "message": "Successful",
#     "data": {
#         "file": "...",
#         "prj_id": 74,
#         "user_id": 133,
#         "org_id": 234,
#         "report_json": {
#             "extent": "298542D4353500004C2455193D2797C328187D4353500004C2477208D2797",
#             "pageLayout": "A4_portrait",
#             "data": {
#                 "layout": "A4 Portrait Report",
#                 "srs": "EPSG:32643",
#                 "units": "m",
#                 "dpi": "56",
#                 "outputFilename": "mapprint",
#                 "outputFormat": "pdf",
#                 "orgImage": "234.png",
#                 "layers": [
#                     {
#                         "type": "OSM",
#                         "baseURL": "https:\\/\\/b.tile.openstreetmap.org",
#                         "singleTile": false,
#                         "tileSize": [
#                             256,
#                             256
#                         ],
# ...

# %%
import requests
import json
import base64

def download_pdf():
    url = "http://192.168.20.59:8092/api/report/getDashBoardReport"
    data = {
        "categoryId": 791,
        "layername": "tbl_road_centerline",
        "attribute": "road_type",
        "extent": "298542D4353500004C2455193D2797C328187D4353500004C2477208D2797",
        "no_class": 3,
        "orgId": 234,
        "type": "distinct",
        "user_access": {
            "theme": 81,
            "vmc_zone": "",
            "vmc_ward": ""
        },
        "epsg": 32643,
        "userType": 3,
        "prjid": 74,
        "pageLayout": "A4_portrait",
        "data": {
            "layout": "A4 Portrait",
            "srs": "EPSG:32643",
            "units": "m",
            "dpi": "56",
            "outputFilename": "mapprint",
            "outputFormat": "pdf",
            "orgImage": "234.png",
            "layers": [
                {
                    "type": "OSM",
                    "baseURL": "https:\/\/b.tile.openstreetmap.org",
                    "singleTile": False,
                    "tileSize": [
                        256,
                        256
                    ],
                    "maxExtent": [
                        -2.00375083392E7,
                        -2.00375083392E7,
                        2.00375083392E7,
                        2.00375083392E7
                    ],
                    "resolutions": [
                        156543.03390625,
                        78271.516953125,
                        39135.758475,
                        19567.8792375,
                        9783.93961875,
                        4891.969809375,
                        2445.9849046875,
                        1222.99245256282,
                        611.496226171875,
                        305.7481130859375,
                        152.87405654296876,
                        76.43702827148438,
                        38.21851413574219,
                        19.109257067871095,
                        9.554628533935547,
                        4.777314266967774,
                        2.388657133483887,
                        1.1943285667419434,
                        0.5971642833709717,
                        0.41999977320012255,
                        0.2799998488000817,
                        0.13999992440004086,
                        0.08399995464002451,
                        0.05599996976001634,
                        0.02799998488000817
                    ],
                    "extension": "png"
                },
                {
                    "authkey": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW",
                    "customParams": {
                        "env": "map_type:map",
                        "viewparams": "category_id:788;style_col_name:0;usertype:3;username:kushal88;cond:;gridparam:;order_col:;qrytype:0;dist:0;reverse_q:0;splfltrtype:st_intersects;refecatid:0;wkt:'';prjid:74;"
                    },
                    "styles": [
                        "234_132_307_ts"
                    ],
                    "tiled": True,
                    "format": "image/png",
                    "srs": "EPSG:32643",
                    "layers": [
                        "citylayers4:overlay_ts_bbox_32643"
                    ],
                    "type": "wms",
                    "name": "Vmc_zone",
                    "baseURL": "http://192.168.20.59:8087/geoserver/"
                },
                {
                    "authkey": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW",
                    "customParams": {
                        "env": "map_type:map",
                        "viewparams": "category_id:789;style_col_name:0;usertype:3;username:kushal88;cond:;gridparam:;order_col:;qrytype:0;dist:0;reverse_q:0;splfltrtype:st_intersects;refecatid:0;wkt:'';prjid:74;"
                    },
                    "styles": [
                        "234_132_306_ts"
                    ],
                    "tiled": True,
                    "format": "image/png",
                    "srs": "EPSG:32643",
                    "layers": [
                        "citylayers4:overlay_ts_bbox_32643"
                    ],
                    "type": "wms",
                    "name": "Vmc_ward",
                    "baseURL": "http://192.168.20.59:8087/geoserver/"
                },
                {
                    "authkey": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW",
                    "customParams": {
                        "time": 1684911532619,
                        "env": "map_type:map",
                        "viewparams": "category_id:790;usertype:3;username:kushal88;qrytype:0;dist:0;splfltrtype:st;wkt:'';prjid:74;user_access:{\"theme\":81\\,\"vmc_zone\":\"\"\\,\"vmc_ward\":\"\"};match:AND;gridparam: "
                    },
                    "styles": [
                        "234_133_390_ts"
                    ],
                    "tiled": True,
                    "format": "image/png",
                    "srs": "EPSG:32643",
                    "layers": [
                        "citylayers4:overlay_ts_bbox_32643"
                    ],
                    "type": "wms",
                    "name": "Fire_station",
                    "baseURL": "http://192.168.20.59:8087/geoserver/"
                },
                {
                    "type": "Vector",
                    "styles": {
                        "1": {
                            "strokeColor": "#ffe085",
                            "strokeWidth": 5,
                            "fillOpacity": 0.2,
                            "fillColor": "#FFFFFF"
                        }
                    },
                    "name": "Measure",
                    "geoJson": {
                        "type": "FeatureCollection",
                        "features": []
                    },
                    "styleProperty": "layer_type"
                }
            ],
            "pages": [
                {
                    "mapTitle": "sf fsf fs sf scheduled",
                    "comment": "sf fsf fs sf scheduled",
                    "bbox": [
                        298542.4353500004,
                        2455193.2797,
                        328187.4353500004,
                        2477208.2797
                    ],
                    "rotation": 0
                }
            ],
            "legends": []
        },
        "url": "http://192.168.20.59:8087/geoserver/pdf/create.json?authkey=8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW"
    }
    headers = {"X-Auth-Token": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW"}

    response = requests.post(url, json=data, headers=headers)

    if response.status_code == 200:
        json_data = response.json()
        
        file_value = json_data.get('data', {}).get('file')
        if file_value:
            pdf_data = base64.b64decode(file_value)
            with open('sample.pdf', 'wb') as file:
                file.write(pdf_data)
            print("PDF file downloaded successfully.")
        else:
            print("Error: File value not found in the response.")
    else:
        print("Error: API request failed.")

download_pdf()
# Out:
# Error: API request failed.

# %%
config = {
    "success": True,
    "message": "Successful",
    "data": {
        "layers": [
            {
                "category_id": 790,
                "cat_name": "Fire_station",
                "attributes": [
                    {
                        "col_alias": "fire_stati",
                        "default_dashboard_col": False,
                        "tbl_name": "tbl_fire_station",
                        "col_name": "fire_stati",
                        "type": "distinct"
                    },
                    {
                        "col_alias": "fire_station_name",
                        "default_dashboard_col": False,
                        "tbl_name": "vehicle_info_1",
                        "col_name": "fire_station_name",
                        "type": "distinct"
                    },
                    {
                        "col_alias": "no_of_ambu",
                        "default_dashboard_col": True,
                        "tbl_name": "tbl_fire_station",
                        "col_name": "no_of_ambu",
                        "type": "quantile"
                    },
                    {
                        "col_alias": "no_of_fire",
                        "default_dashboard_col": False,
                        "tbl_name": "tbl_fire_station",
                        "col_name": "no_of_fire",
                        "type": "quantile"
                    },
                    {
                        "col_alias": "vehcl_id",
                        "default_dashboard_col": False,
                        "tbl_name": "vehicle_info_1",
                        "col_name": "vehcl_id",
                        "type": "quantile"
                    }
                ],
                "table_name": "tbl_fire_station",
                "layer_type": "operational"
            },
            {
                "category_id": 791,
                "cat_name": "Road_centerline",
                "attributes": [
                    {
                        "col_alias": "road_name",
                        "default_dashboard_col": False,
                        "tbl_name": "tbl_road_centerline",
                        "col_name": "road_name",
                        "type": "distinct"
                    },
                    {
                        "col_alias": "road_type",
                        "default_dashboard_col": False,
                        "tbl_name": "tbl_road_centerline",
                        "col_name": "road_type",
                        "type": "distinct"
                    },
                    {
                        "col_alias": "road_width",
                        "default_dashboard_col": False,
                        "tbl_name": "tbl_road_centerline",
                        "col_name": "road_width",
                        "type": "quantile"
                    }
                ],
                "table_name": "tbl_road_centerline",
                "layer_type": "operational"
            },
            {
                "category_id": 792,
                "cat_name": "Slum_boundary",
                "attributes": [
                    {
                        "col_alias": "slum_name",
                        "default_dashboard_col": True,
                        "tbl_name": "tbl_slum_boundary",
                        "col_name": "slum_name",
                        "type": "distinct"
                    }
                ],
                "table_name": "tbl_slum_boundary",
                "layer_type": "operational"
            }
        ]
    },
    "funName": "webservice.fn_geoportal_dashboardlayers",
    "funInputs": "133,0,234,25,3,114,74"
}

# %%
json_data = config["data"]["layers"][0]["attributes"]
project_data = [(obj['col_alias'], obj['type']) for obj in json_data]
print(project_data)



json_data = config["data"]["layers"][1]["attributes"]
project_data = [(obj['col_alias'], obj['type']) for obj in json_data]
print(project_data)


json_data = config["data"]["layers"][2]["attributes"]
project_data = [(obj['col_alias'], obj['type']) for obj in json_data]
print(project_data)
# Out:
# [('fire_stati', 'distinct'), ('fire_station_name', 'distinct'), ('no_of_ambu', 'quantile'), ('no_of_fire', 'quantile'), ('vehcl_id', 'quantile')]
# [('road_name', 'distinct'), ('road_type', 'distinct'), ('road_width', 'quantile')]
# [('slum_name', 'distinct')]

# %%
def validate_attribute(attribute_name):
    json_data = config["data"]["layers"]

    for layer in json_data:
        attributes = layer.get("attributes")
        if attributes:
            for attribute in attributes:
                col_alias = attribute.get("col_alias")
                if col_alias and col_alias.lower() == attribute_name.lower():
                    col_alias_value = col_alias
                    attribute_type = attribute.get("type")
                    return col_alias_value, attribute_type

    return None, None


# User input attribute name
user_input = input("Enter attribute name: ")
col_alias_value, attribute_type = validate_attribute(user_input)

if col_alias_value and attribute_type:
    print(f"The attribute name '{user_input}' is valid.")
    print(f"Col_alias: {col_alias_value}")
    print(f"Type: {attribute_type}")
    # Additional actions using col_alias_value and attribute_type if required

else:
    print(f"The attribute name '{user_input}' is invalid.")
    # Additional actions for invalid attribute name
# Out:
# Enter attribute name: fire_stati
# The attribute name 'fire_stati' is valid.
# Col_alias: fire_stati
# Type: distinct

# %%
def get_attribute_list():
    attribute_list = []

    json_data = config["data"]["layers"]

    for layer in json_data:
        attributes = layer.get("attributes")
        if attributes:
            attribute_list.extend([attr["col_alias"] for attr in attributes])

    return attribute_list


# Get attribute list
attribute_list = get_attribute_list()

# Print attribute list
print("Available attributes:")
for attribute in attribute_list:
    print(attribute)

# Choose attribute
user_input = input("Enter attribute name: ")

if user_input in attribute_list:
    print(f"You selected attribute: {user_input}")
    # Additional actions using user_input if required

else:
    print("Invalid attribute name. Please select a valid attribute.")
    # Additional actions for invalid attribute name
# Out:
# Available attributes:
# fire_stati
# fire_station_name
# no_of_ambu
# no_of_fire
# vehcl_id
# road_name
# road_type
# road_width
# slum_name
# Enter attribute name: fire_stati
# You selected attribute: fire_stati

# %%
import requests

class FetchAndPrintColAliases:
    def __init__(self):
        self.category_id = None

    def fetch_col_aliases(self, selected_category):
        url = "http://192.168.20.61:8080/geoportal/api/dashboard/getDashboardLayers"
        data = {"orgId": 234, "usertype": 3, "page": 1, "start": 0, "limit": 25}
        headers = {"X-Auth-Token": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW"}

        response = requests.post(url, json=data, headers=headers)

        if response.status_code == 200:
            json_data = response.json()

            if 'data' in json_data and 'layers' in json_data['data']:
                layers = json_data['data']['layers']

                for layer in layers:
                    if layer['cat_name'] == selected_category:
                        self.category_id = layer.get('category_id')

                        if self.category_id:
                            attributes = layer.get('attributes')

                            if attributes:
                                col_aliases = [attr['col_alias'] for attr in attributes]
                                return col_aliases

        return []

class ValidateAttributeAction:
    def __init__(self):
        self.col_alias_value = None
        self.attribute_type = None

    def validate_attribute(self, attribute_name, col_aliases):
        for col_alias in col_aliases:
            if col_alias.lower() == attribute_name.lower():
                self.col_alias_value = col_alias
                self.attribute_type = "some_type"

                return True

        return False

# Usage example
fetcher = FetchAndPrintColAliases()
validator = ValidateAttributeAction()

# Fetch col_aliases for a selected category
selected_category = "Fire_station"
col_aliases = fetcher.fetch_col_aliases(selected_category)
if col_aliases:
    print(f"Col_aliases for {selected_category}: {col_aliases}")
else:
    print(f"No col_aliases found for {selected_category}")

# Validate an attribute
attribute_name = "fire_stati"
if validator.validate_attribute(attribute_name, col_aliases):
    print(f"Valid attribute: {attribute_name}")
    print(f"Col_alias: {validator.col_alias_value}")
    print(f"Type: {validator.attribute_type}")
else:
    print(f"Invalid attribute: {attribute_name}")
# Out:
# Col_aliases for Fire_station: ['fire_stati', 'fire_station_name', 'no_of_ambu', 'no_of_fire', 'vehcl_id']
# Valid attribute: fire_stati
# Col_alias: fire_stati
# Type: some_type

# %%
def validate_attribute(attribute_name):
    # Access the JSON data (assuming it is stored in the 'config' variable)
    json_data = config["data"]["layers"]

    # Iterate through each layer
    for layer in json_data:
        attributes = layer.get("attributes")
        if attributes:
            # Iterate through each attribute in the layer
            for attribute in attributes:
                col_alias = attribute.get("col_alias")
                if col_alias and col_alias.lower() == attribute_name.lower():
                    col_alias_value = col_alias
                    attribute_type = attribute.get("type")
                    return col_alias_value, attribute_type

    return None, None


# User input attribute name
user_input = input("Enter attribute name: ")
col_alias_value, attribute_type = validate_attribute(user_input)

if col_alias_value and attribute_type:
    print(f"The attribute name '{user_input}' is valid.")
    print(f"Col_alias: {col_alias_value}")
    print(f"Type: {attribute_type}")
    # Additional actions using col_alias_value and attribute_type if required

else:
    print(f"The attribute name '{user_input}' is invalid.")
    # Additional actions for invalid attribute name if required
# Out:
# Enter attribute name: fire_station_name
# The attribute name 'fire_station_name' is valid.
# Col_alias: fire_station_name
# Type: distinct

# %%
import requests
import json
import base64

def download_pdf():
    url = "http://192.168.20.59:8092/api/report/getDashBoardReport"
    data = {
    "categoryId": 791,
    "layername": "tbl_road_centerline",
    "attribute": "road_type",
    "extent": "298542D4353500004C2455193D2797C328187D4353500004C2477208D2797",
    "no_class": 3,
    "orgId": 234,
    "type": "distinct",
    "user_access": {
        "theme": 81,
        "vmc_zone": "",
        "vmc_ward": ""
    },
    "epsg": 32643,
    "userType": 3,
    "prjid": 74,
    "pageLayout": "A4_portrait",
    "data": {
        "layout": "A4 Portrait",
        "srs": "EPSG:32643",
        "units": "m",
        "dpi": "56",
        "outputFilename": "mapprint",
        "outputFormat": "pdf",
        "orgImage": "234.png",
        "layers": [
            {
                "type": "OSM",
                "baseURL": "https:\\/\\/b.tile.openstreetmap.org",
                "singleTile": False,
                "tileSize": [
                    256,
                    256
                ],
                "maxExtent": [
                    -20037508.3392,
                    -20037508.3392,
                    20037508.3392,
                    20037508.3392
                ],
                "resolutions": [
                    156543.03390625,
                    78271.516953125,
                    39135.758475,
                    19567.8792375,
                    9783.93961875,
                    4891.969809375,
                    2445.9849046875,
                    1222.99245256282,
                    611.496226171875,
                    305.7481130859375,
                    152.87405654296876,
                    76.43702827148438,
                    38.21851413574219,
                    19.109257067871095,
                    9.554628533935547,
                    4.777314266967774,
                    2.388657133483887,
                    1.1943285667419434,
                    0.5971642833709717,
                    0.41999977320012255,
                    0.2799998488000817,
                    0.13999992440004086,
                    0.08399995464002451,
                    0.05599996976001634,
                    0.02799998488000817
                ],
                "extension": "png"
            },
            {
                "authkey": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW",
                "customParams": {
                    "env": "map_type:map",
                    "viewparams": "category_id:788;style_col_name:0;usertype:3;username:kushal88;cond:;gridparam:;order_col:;qrytype:0;dist:0;reverse_q:0;splfltrtype:st_intersects;refecatid:0;wkt:'';prjid:74;"
                },
                "styles": [
                    "234_132_307_ts"
                ],
                "tiled": True,
                "format": "image/png",
                "srs": "EPSG:32643",
                "layers": [
                    "citylayers4:overlay_ts_bbox_32643"
                ],
                "type": "wms",
                "name": "vmc_zone",
                "baseURL": "http://192.168.20.59:8087/geoserver/"
            },
            {
                "authkey": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW",
                "customParams": {
                    "env": "map_type:map",
                    "viewparams": "category_id:789;style_col_name:0;usertype:3;username:kushal88;cond:;gridparam:;order_col:;qrytype:0;dist:0;reverse_q:0;splfltrtype:st_intersects;refecatid:0;wkt:'';prjid:74;"
                },
                "styles": [
                    "234_132_306_ts"
                ],
                "tiled": True,
                "format": "image/png",
                "srs": "EPSG:32643",
                "layers": [
                    "citylayers4:overlay_ts_bbox_32643"
                ],
                "type": "wms",
                "name": "Vmc_ward",
                "baseURL": "http://192.168.20.59:8087/geoserver/"
            },
            {
                "authkey": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW",
                "customParams": {
                    "time": 1684911532619,
                    "env": "map_type:map",
                    "viewparams": "category_id:790;usertype:3;username:kushal88;qrytype:0;dist:0;splfltrtype:st;wkt:'';prjid:74;user_access:{\"theme\":81\\,\"vmc_zone\":\"\"\\,\"vmc_ward\":\"\"};match:AND;gridparam: "
                },
                "styles": [
                    "234_133_390_ts"
                ],
                "tiled": True,
                "format": "image/png",
                "srs": "EPSG:32643",
                "layers": [
                    "citylayers4:overlay_ts_bbox_32643"
                ],
                "type": "wms",
                "name": "Fire_station",
                "baseURL": "http://192.168.20.59:8087/geoserver/"
            },
            {
                "type": "Vector",
                "styles": {
                    "1": {
                        "strokeColor": "#ffe085",
                        "strokeWidth": 5,
                        "fillOpacity": 0.2,
                        "fillColor": "#FFFFFF"
                    }
                },
                "name": "Measure",
                "geoJson": {
                    "type": "FeatureCollection",
                    "features": []
                },
                "styleProperty": "layer_type"
            }
        ],
        "pages": [
            {
                "mapTitle": "sf fsf fs sf scheduled",
                "comment": "sf fsf fs sf scheduled",
                "bbox": [
                    298542.4353500004,
                    2455193.2797,
                    328187.4353500004,
                    2477208.2797
                ],
                "rotation": 0
            }
        ],
        "legends": []
    },
    "url": "http://192.168.20.59:8087/geoserver/pdf/create.json?authkey=8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW"
}
    headers = {"X-Auth-Token": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW"}

    response = requests.post(url, json=data, headers=headers)

    if response.status_code == 200:
        json_data = response.json()
        
        file_value = json_data.get('data', {}).get('file')
        if file_value:
            pdf_data = base64.b64decode(file_value)
            with open('sample.pdf', 'wb') as file:
                file.write(pdf_data)
            print("PDF file downloaded successfully.")
        else:
            print("Error: File value not found in the response.")
    else:
        print("Error: API request failed.")

download_pdf()
# Out:
# Error: API request failed.

# %% [markdown]
# # Showing Json Data

# %%
import requests
import json
import base64

def get_json_data():
    url = "http://192.168.20.59:8092/api/report/getDashBoardReport"
    data = {
    "categoryId": 791,
    "layername": "tbl_road_centerline",
    "attribute": "road_type",
    "extent": "298542D4353500004C2455193D2797C328187D4353500004C2477208D2797",
    "no_class": 3,
    "orgId": 234,
    "type": "distinct",
    "user_access": {
        "theme": 81,
        "vmc_zone": "",
        "vmc_ward": ""
    },
    "epsg": 32643,
    "userType": 3,
    "prjid": 74,
    "pageLayout": "A4_portrait",
    "data": {
        "layout": "A4 Portrait",
        "srs": "EPSG:32643",
        "units": "m",
        "dpi": "56",
        "outputFilename": "mapprint",
        "outputFormat": "pdf",
        "orgImage": "234.png",
        "layers": [
            {
                "type": "OSM",
                "baseURL": "https:\\/\\/b.tile.openstreetmap.org",
                "singleTile": False,
                "tileSize": [
                    256,
                    256
                ],
                "maxExtent": [
                    -20037508.3392,
                    -20037508.3392,
                    20037508.3392,
                    20037508.3392
                ],
                "resolutions": [
                    156543.03390625,
                    78271.516953125,
                    39135.758475,
                    19567.8792375,
                    9783.93961875,
                    4891.969809375,
                    2445.9849046875,
                    1222.99245256282,
                    611.496226171875,
                    305.7481130859375,
                    152.87405654296876,
                    76.43702827148438,
                    38.21851413574219,
                    19.109257067871095,
                    9.554628533935547,
                    4.777314266967774,
                    2.388657133483887,
                    1.1943285667419434,
                    0.5971642833709717,
                    0.41999977320012255,
                    0.2799998488000817,
                    0.13999992440004086,
                    0.08399995464002451,
                    0.05599996976001634,
                    0.02799998488000817
                ],
                "extension": "png"
            },
            {
                "authkey": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW",
                "customParams": {
                    "env": "map_type:map",
                    "viewparams": "category_id:788;style_col_name:0;usertype:3;username:kushal88;cond:;gridparam:;order_col:;qrytype:0;dist:0;reverse_q:0;splfltrtype:st_intersects;refecatid:0;wkt:'';prjid:74;"
                },
                "styles": [
                    "234_132_307_ts"
                ],
                "tiled": True,
                "format": "image/png",
                "srs": "EPSG:32643",
                "layers": [
                    "citylayers4:overlay_ts_bbox_32643"
                ],
                "type": "wms",
                "name": "vmc_zone",
                "baseURL": "http://192.168.20.59:8087/geoserver/"
            },
            {
                "authkey": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW",
                "customParams": {
                    "env": "map_type:map",
                    "viewparams": "category_id:789;style_col_name:0;usertype:3;username:kushal88;cond:;gridparam:;order_col:;qrytype:0;dist:0;reverse_q:0;splfltrtype:st_intersects;refecatid:0;wkt:'';prjid:74;"
                },
                "styles": [
                    "234_132_306_ts"
                ],
                "tiled": True,
                "format": "image/png",
                "srs": "EPSG:32643",
                "layers": [
                    "citylayers4:overlay_ts_bbox_32643"
                ],
                "type": "wms",
                "name": "Vmc_ward",
                "baseURL": "http://192.168.20.59:8087/geoserver/"
            },
            {
                "authkey": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW",
                "customParams": {
                    "time": 1684911532619,
                    "env": "map_type:map",
                    "viewparams": "category_id:790;usertype:3;username:kushal88;qrytype:0;dist:0;splfltrtype:st;wkt:'';prjid:74;user_access:{\"theme\":81\\,\"vmc_zone\":\"\"\\,\"vmc_ward\":\"\"};match:AND;gridparam: "
                },
                "styles": [
                    "234_133_390_ts"
                ],
                "tiled": True,
                "format": "image/png",
                "srs": "EPSG:32643",
                "layers": [
                    "citylayers4:overlay_ts_bbox_32643"
                ],
                "type": "wms",
                "name": "Fire_station",
                "baseURL": "http://192.168.20.59:8087/geoserver/"
            },
            {
                "type": "Vector",
                "styles": {
                    "1": {
                        "strokeColor": "#ffe085",
                        "strokeWidth": 5,
                        "fillOpacity": 0.2,
                        "fillColor": "#FFFFFF"
                    }
                },
                "name": "Measure",
                "geoJson": {
                    "type": "FeatureCollection",
                    "features": []
                },
                "styleProperty": "layer_type"
            }
        ],
        "pages": [
            {
                "mapTitle": "sf fsf fs sf scheduled",
                "comment": "sf fsf fs sf scheduled",
                "bbox": [
                    298542.4353500004,
                    2455193.2797,
                    328187.4353500004,
                    2477208.2797
                ],
                "rotation": 0
            }
        ],
        "legends": []
    },
    "url": "http://192.168.20.59:8087/geoserver/pdf/create.json?authkey=8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW"
 }
    headers = {"X-Auth-Token": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW"}

    response = requests.post(url, json=data, headers=headers)

    if response.status_code == 200:
        json_data = response.json()
        print(json.dumps(json_data, indent=4))  # Print the JSON response for inspection
        
        file_value = json_data.get('data', {}).get('file')
        if file_value:
            pdf_data = base64.b64decode(file_value)
            with open('output.pdf', 'wb') as file:
                file.write(pdf_data)
            print("PDF file downloaded.")
        else:
            print("Error: File value not found in the response.")
    else:
        print("Error: API request failed.")

get_json_data()
# Out:
# Error: API request failed.

# %%
import requests
import json
import base64

def get_json_data():
    url = "http://192.168.20.59:8092/api/report/getDashBoardReport"
    data = {
        
    "categoryId": 791,
    "layername": "tbl_road_centerline",
    "attribute": "road_type",
    "extent": "298542D4353500004C2455193D2797C328187D4353500004C2477208D2797",
    "no_class": 3,
    "orgId": 234,
    "type": "distinct",
    "user_access": {
        "theme": 81,
        "vmc_zone": "",
        "vmc_ward": ""
    },
    "epsg": 32643,
    "userType": 3,
    "prjid": 74,
    "pageLayout": "A4_portrait",
    "data": {
        "layout": "A4 Portrait",
        "srs": "EPSG:32643",
        "units": "m",
        "dpi": "56",
        "outputFilename": "mapprint",
        "outputFormat": "pdf",
        "orgImage": "234.png",
        "layers": [
            {
                "type": "OSM",
                "baseURL": "https:\\/\\/b.tile.openstreetmap.org",
                "singleTile": False,
                "tileSize": [
                    256,
                    256
                ],
                "maxExtent": [
                    -20037508.3392,
                    -20037508.3392,
                    20037508.3392,
                    20037508.3392
                ],
                "resolutions": [
                    156543.03390625,
                    78271.516953125,
                    39135.758475,
                    19567.8792375,
                    9783.93961875,
                    4891.969809375,
                    2445.9849046875,
                    1222.99245256282,
                    611.496226171875,
                    305.7481130859375,
                    152.87405654296876,
                    76.43702827148438,
                    38.21851413574219,
                    19.109257067871095,
                    9.554628533935547,
                    4.777314266967774,
                    2.388657133483887,
                    1.1943285667419434,
                    0.5971642833709717,
                    0.41999977320012255,
                    0.2799998488000817,
                    0.13999992440004086,
                    0.08399995464002451,
                    0.05599996976001634,
                    0.02799998488000817
                ],
                "extension": "png"
            },
            {
                "authkey": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW",
                "customParams": {
                    "env": "map_type:map",
                    "viewparams": "category_id:788;style_col_name:0;usertype:3;username:kushal88;cond:;gridparam:;order_col:;qrytype:0;dist:0;reverse_q:0;splfltrtype:st_intersects;refecatid:0;wkt:'';prjid:74;"
                },
                "styles": [
                    "234_132_307_ts"
                ],
                "tiled": True,
                "format": "image/png",
                "srs": "EPSG:32643",
                "layers": [
                    "citylayers4:overlay_ts_bbox_32643"
                ],
                "type": "wms",
                "name": "vmc_zone",
                "baseURL": "http://192.168.20.59:8087/geoserver/"
            },
            {
                "authkey": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW",
                "customParams": {
                    "env": "map_type:map",
                    "viewparams": "category_id:789;style_col_name:0;usertype:3;username:kushal88;cond:;gridparam:;order_col:;qrytype:0;dist:0;reverse_q:0;splfltrtype:st_intersects;refecatid:0;wkt:'';prjid:74;"
                },
                "styles": [
                    "234_132_306_ts"
                ],
                "tiled": True,
                "format": "image/png",
                "srs": "EPSG:32643",
                "layers": [
                    "citylayers4:overlay_ts_bbox_32643"
                ],
                "type": "wms",
                "name": "Vmc_ward",
                "baseURL": "http://192.168.20.59:8087/geoserver/"
            },
            {
                "authkey": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW",
                "customParams": {
                    "time": 1684911532619,
                    "env": "map_type:map",
                    "viewparams": "category_id:790;usertype:3;username:kushal88;qrytype:0;dist:0;splfltrtype:st;wkt:'';prjid:74;user_access:{\"theme\":81\\,\"vmc_zone\":\"\"\\,\"vmc_ward\":\"\"};match:AND;gridparam: "
                },
                "styles": [
                    "234_133_390_ts"
                ],
                "tiled": True,
                "format": "image/png",
                "srs": "EPSG:32643",
                "layers": [
                    "citylayers4:overlay_ts_bbox_32643"
                ],
                "type": "wms",
                "name": "Fire_station",
                "baseURL": "http://192.168.20.59:8087/geoserver/"
            },
            {
                "type": "Vector",
                "styles": {
                    "1": {
                        "strokeColor": "#ffe085",
                        "strokeWidth": 5,
                        "fillOpacity": 0.2,
                        "fillColor": "#FFFFFF"
                    }
                },
                "name": "Measure",
                "geoJson": {
                    "type": "FeatureCollection",
                    "features": []
                },
                "styleProperty": "layer_type"
            }
        ],
        "pages": [
            {
                "mapTitle": "sf fsf fs sf scheduled",
                "comment": "sf fsf fs sf scheduled",
                "bbox": [
                    298542.4353500004,
                    2455193.2797,
                    328187.4353500004,
                    2477208.2797
                ],
                "rotation": 0
            }
        ],
        "legends": []
    },
    "url": "http://192.168.20.59:8087/geoserver/pdf/create.json?authkey=8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW"
}
    
    headers = {"X-Auth-Token": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW"}

    try:
        with requests.Session() as session:
            response = session.post(url, json=data, headers=headers)
            response.raise_for_status()  # Raise an exception for non-200 status codes

            json_data = response.json()
            print(json.dumps(json_data, indent=4))

            file_value = json_data.get('data', {}).get('file')
            if file_value:
                pdf_data = base64.b64decode(file_value)
                with open('output.pdf', 'wb') as file:
                    file.write(pdf_data)
                print("PDF file downloaded.")
            else:
                print("Error: File value not found in the response.")
    except requests.exceptions.RequestException as e:
        print(f"Error: {str(e)}")
    except json.JSONDecodeError as e:
        print(f"Error: Failed to decode JSON response - {str(e)}")

get_json_data()
# Out:
# Error: 500 Server Error:  for url: http://192.168.20.59:8092/api/report/getDashBoardReport

# %%
import requests
import json
import base64

def get_json_data():
    url = "http://192.168.20.59:8092/api/report/getDashBoardReport"
    
    data = {
        "categoryId": 791,
        "layername": "tbl_road_centerline",
        "attribute": "road_type",
        "extent": "298542D4353500004C2455193D2797C328187D4353500004C2477208D2797",
        "no_class": 3,
        "orgId": 234,
        "type": "distinct",
        "user_access": {
            "theme": 81,
            "vmc_zone": "",
            "vmc_ward": ""
        },
        "epsg": 32643,
        "userType": 3,
        "prjid": 74,
        "pageLayout": "A4_portrait",
        "data": {
            "layout": "A4 Portrait",
            "srs": "EPSG:32643",
            "units": "m",
            "dpi": "56",
            "outputFilename": "mapprint",
            "outputFormat": "pdf",
            "orgImage": "234.png",
            "layers": [
                {
                    "type": "OSM",
                    "baseURL": "https://b.tile.openstreetmap.org",
                    "singleTile": False,
                    "tileSize": [
                        256,
                        256
                    ],
                    "maxExtent": [
                        -20037508.3392,
                        -20037508.3392,
                        20037508.3392,
                        20037508.3392
                    ],
                    "resolutions": [
                        156543.03390625,
                        78271.516953125,
                        39135.758475,
                        19567.8792375,
                        9783.93961875,
                        4891.969809375,
                        2445.9849046875,
                        1222.99245256282,
                        611.496226171875,
                        305.7481130859375,
                        152.87405654296876,
                        76.43702827148438,
                        38.21851413574219,
                        19.109257067871095,
                        9.554628533935547,
                        4.777314266967774,
                        2.388657133483887,
                        1.1943285667419434,
                        0.5971642833709717,
                        0.41999977320012255,
                        0.2799998488000817,
                        0.13999992440004086,
                        0.08399995464002451,
                        0.05599996976001634,
                        0.02799998488000817
                    ],
                    "extension": "png"
                },
                {
                    "authkey": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW",
                    "customParams": {
                        "env": "map_type:map",
                        "viewparams": "category_id:788;style_col_name:0;usertype:3;username:kushal88;cond:;gridparam:;order_col:;qrytype:0;dist:0;reverse_q:0;splfltrtype:st_intersects;refecatid:0;wkt:'';prjid:74;"
                    },
                    "styles": [
                        "234_132_307_ts"
                    ],
                    "tiled": True,
                    "format": "image/png",
                    "srs": "EPSG:32643",
                    "layers": [
                        "citylayers4:overlay_ts_bbox_32643"
                    ],
                    "type": "wms",
                    "name": "vmc_zone",
                    "baseURL": "http://192.168.20.59:8087/geoserver/"
                },
                {
                    "authkey": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW",
                    "customParams": {
                        "env": "map_type:map",
                        "viewparams": "category_id:789;style_col_name:0;usertype:3;username:kushal88;cond:;gridparam:;order_col:;qrytype:0;dist:0;reverse_q:0;splfltrtype:st_intersects;refecatid:0;wkt:'';prjid:74;"
                    },
                    "styles": [
                        "234_132_306_ts"
                    ],
                    "tiled": True,
                    "format": "image/png",
                    "srs": "EPSG:32643",
                    "layers": [
                        "citylayers4:overlay_ts_bbox_32643"
                    ],
                    "type": "wms",
                    "name": "Vmc_ward",
                    "baseURL": "http://192.168.20.59:8087/geoserver/"
                },
                {
                    "authkey": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW",
                    "customParams": {
                        "time": 1684911532619,
                        "env": "map_type:map",
                        "viewparams": "category_id:790;usertype:3;username:kushal88;qrytype:0;dist:0;splfltrtype:st;wkt:'';prjid:74;user_access:{\"theme\":81\\,\"vmc_zone\":\"\"\\,\"vmc_ward\":\"\"};match:AND;gridparam: "
                    },
                    "styles": [
                        "234_133_390_ts"
                    ],
                    "tiled": True,
                    "format": "image/png",
                    "srs": "EPSG:32643",
                    "layers": [
                        "citylayers4:overlay_ts_bbox_32643"
                    ],
                    "type": "wms",
                    "name": "Fire_station",
                    "baseURL": "http://192.168.20.59:8087/geoserver/"
                },
                {
                    "type": "Vector",
                    "styles": {
                        "1": {
                            "strokeColor": "#ffe085",
                            "strokeWidth": 5,
                            "fillOpacity": 0.2,
                            "fillColor": "#FFFFFF"
                        }
                    },
                    "name": "Measure",
                    "geoJson": {
                        "type": "FeatureCollection",
                        "features": []
                    },
                    "styleProperty": "layer_type"
                }
            ],
            "pages": [
                {
                    "mapTitle": "sf fsf fs sf scheduled",
                    "comment": "sf fsf fs sf scheduled",
                    "bbox": [
                        298542.4353500004,
                        2455193.2797,
                        328187.4353500004,
                        2477208.2797
                    ],
                    "rotation": 0
                }
            ],
            "legends": []
        },
        "url": "http://192.168.20.59:8087/geoserver/pdf/create.json?authkey=8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW"
    }
    
    headers = {"X-Auth-Token": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW"}
    
    response = requests.post(url, json=data, headers=headers)
    
    if response.status_code == 200:
        json_data = response.json()
        return json_data
    else:
        return None

# Example usage
json_data = get_json_data()


print(json_data)

# # Extracting the file key from the JSON response
# if json_data is not None and "fileKey" in json_data:
#     file_key = json_data["fileKey"]
#     print("File Key:", file_key)
# Out:
# {'success': True, 'message': 'Successful', 'data': {'file': '...', 'prj_id': 74, 'user_id': 133, 'org_id': 234, 'report_json': {'extent': '298542D4353500004C2455193D2797C328187D4353500004C2477208D2797', 'pageLayout': 'A4_portrait', 'data': {'layout': 'A4 Portrait Report', 'srs': 'EPSG:32643', 'units': 'm', 'dpi': '56', 'outputFilename': 'mapprint', 'outputFormat': 'pdf', 'orgImage': '234.png', 'layers': [{'type': 'OSM', 'baseURL': 'https://b.tile.openstreetmap.org', 'singleTile': False, 'tileSize': [256, 256], 'maxExtent': [-20037508.3392, -20037508.3392, 20037508.3392, 20037508.3392], 'resolutions': [156543.03390625, 78271.516953125, 39135.758475, 19567.8792375, 9783.93961875, 4891.969809375, 2445.9849046875, 1222.99245256282, 611.496226171875, 305.7481130859375, 152.87405654296876, 76.43702827148438, 38.21851413574219, 19.109257067871095, 9.554628533935547, 4.777314266967774, 2.388657133483887, 1.1943285667419434, 0.5971642833709717, 0.41999977320012255, 0.2799998488000817, 0.13999
# ...

# %%
import requests
import base64

def get_pdf_data():
    url = "http://192.168.20.59:8092/api/report/getDashBoardReport"
    data = {
        "categoryId": 791,
        "layername": "tbl_road_centerline",
        "attribute": "road_type",
        "extent": "298542D4353500004C2455193D2797C328187D4353500004C2477208D2797",
        "no_class": 3,
        "orgId": 234,
        "type": "distinct",
        "user_access": {
            "theme": 81,
            "vmc_zone": "",
            "vmc_ward": ""
        },
        "epsg": 32643,
        "userType": 3,
        "prjid": 74,
        "pageLayout": "A4_portrait",
        "data": {
            "layout": "A4 Portrait",
            "srs": "EPSG:32643",
            "units": "m",
            "dpi": "56",
            "outputFilename": "mapprint",
            "outputFormat": "pdf",
            "orgImage": "234.png",
            "layers": [
                {
                    "type": "OSM",
                    "baseURL": "https://b.tile.openstreetmap.org",
                    "singleTile": False,
                    "tileSize": [
                        256,
                        256
                    ],
                    "maxExtent": [
                        -20037508.3392,
                        -20037508.3392,
                        20037508.3392,
                        20037508.3392
                    ],
                    "resolutions": [
                        156543.03390625,
                        78271.516953125,
                        39135.758475,
                        19567.8792375,
                        9783.93961875,
                        4891.969809375,
                        2445.9849046875,
                        1222.99245256282,
                        611.496226171875,
                        305.7481130859375,
                        152.87405654296876,
                        76.43702827148438,
                        38.21851413574219,
                        19.109257067871095,
                        9.554628533935547,
                        4.777314266967774,
                        2.388657133483887,
                        1.1943285667419434,
                        0.5971642833709717,
                        0.41999977320012255,
                        0.2799998488000817,
                        0.13999992440004086,
                        0.08399995464002451,
                        0.05599996976001634,
                        0.02799998488000817
                    ],
                    "extension": "png"
                },
                {
                    "authkey": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW",
                    "customParams": {
                        "env": "map_type:map",
                        "viewparams": "category_id:788;style_col_name:0;usertype:3;username:kushal88;cond:;gridparam:;order_col:;qrytype:0;dist:0;reverse_q:0;splfltrtype:st_intersects;refecatid:0;wkt:'';prjid:74;"
                    },
                    "styles": [
                        "234_132_307_ts"
                    ],
                    "tiled": True,
                    "format": "image/png",
                    "srs": "EPSG:32643",
                    "layers": [
                        "citylayers4:overlay_ts_bbox_32643"
                    ],
                    "type": "wms",
                    "name": "vmc_zone",
                    "baseURL": "http://192.168.20.59:8087/geoserver/"
                },
                {
                    "authkey": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW",
                    "customParams": {
                        "env": "map_type:map",
                        "viewparams": "category_id:789;style_col_name:0;usertype:3;username:kushal88;cond:;gridparam:;order_col:;qrytype:0;dist:0;reverse_q:0;splfltrtype:st_intersects;refecatid:0;wkt:'';prjid:74;"
                    },
                    "styles": [
                        "234_132_306_ts"
                    ],
                    "tiled": True,
                    "format": "image/png",
                    "srs": "EPSG:32643",
                    "layers": [
                        "citylayers4:overlay_ts_bbox_32643"
                    ],
                    "type": "wms",
                    "name": "Vmc_ward",
                    "baseURL": "http://192.168.20.59:8087/geoserver/"
                },
                {
                    "authkey": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW",
                    "customParams": {
                        "time": 1684911532619,
                        "env": "map_type:map",
                        "viewparams": "category_id:790;usertype:3;username:kushal88;qrytype:0;dist:0;splfltrtype:st;wkt:'';prjid:74;user_access:{\"theme\":81\\,\"vmc_zone\":\"\"\\,\"vmc_ward\":\"\"};match:AND;gridparam: "
                    },
                    "styles": [
                        "234_133_390_ts"
                    ],
                    "tiled": True,
                    "format": "image/png",
                    "srs": "EPSG:32643",
                    "layers": [
                        "citylayers4:overlay_ts_bbox_32643"
                    ],
                    "type": "wms",
                    "name": "Fire_station",
                    "baseURL": "http://192.168.20.59:8087/geoserver/"
                },
                {
                    "type": "Vector",
                    "styles": {
                        "1": {
                            "strokeColor": "#ffe085",
                            "strokeWidth": 5,
                            "fillOpacity": 0.2,
                            "fillColor": "#FFFFFF"
                        }
                    },
                    "name": "Measure",
                    "geoJson": {
                        "type": "FeatureCollection",
                        "features": []
                    },
                    "styleProperty": "layer_type"
                }
            ],
            "pages": [
                {
                    "mapTitle": "sf fsf fs sf scheduled",
                    "comment": "sf fsf fs sf scheduled",
                    "bbox": [
                        298542.4353500004,
                        2455193.2797,
                        328187.4353500004,
                        2477208.2797
                    ],
                    "rotation": 0
                }
            ],
            "legends": []
        },
        "url": "http://192.168.20.59:8087/geoserver/pdf/create.json?authkey=8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW"
    }
    
    headers = {"X-Auth-Token": "8rt5qVm4JMK6A7lrWdd8dgDg4woP1RLW"}
    
    response = requests.post(url, json=data, headers=headers)
    
    if response.status_code == 200:
        json_data = response.json()
        return json_data
    else:
        return None

# Example usage
json_data = get_pdf_data()

if json_data is not None and "data" in json_data and "file" in json_data["data"]:
    base64_data = json_data["data"]["file"]
    pdf_data = base64.b64decode(base64_data)
    
    # Save the PDF to a file
    with open("output1.pdf", "wb") as file:
        file.write(pdf_data)
        
    print("PDF saved successfully.")
else:
    print("Failed to retrieve PDF data.")
# Out:
# PDF saved successfully.
